# %% [markdown]
# # Pizza recommendation on Amazon SageMaker with Factorization Machines

# %% [markdown]
# ### Use this OLO dataset

# %%
# !head -10 UpdatedOLOdata.csv
# Out:
# UserID,OrderDate,Month,Order ID,BPO,MenuCode,SizeCode,CouponCode,Price,Flag_CorePizza,Flag_PizzaMania,Flag_EdvReg,Flag_EDVMed,Flag_Side,Flag_Dessert,OrderDateInEpoch
# 6207089.068,4-Feb-18, 2 ,DPI66285_43135_174,289,PIZ0103,HT07,,69,0,1,0,0,0,0,1517702400
# 6207089.068,04-02-18, 2 ,DPI66285_43135_174,289,PIZ0104,HT07,,75,0,1,0,0,0,0,1517702400
# 6207089.068,04-02-18, 2 ,DPI66285_43135_174,289,VGPARCEL,PVEG01,,35,0,0,0,0,1,0,1517702400
# 6207089.068,08-02-18, 2 ,DPI66285_43139_158,165,PIZ0100,BHT07,,165,1,0,0,0,0,0,1518048000
# 6207089.068,18-02-18, 2 ,DPI66285_43149_76,165,PIZ0100,BHT07,,165,1,0,0,0,0,0,1518912000
# 6207089.068,23-03-18, 3 ,DPI66285_43182_20,165,PIZ0100,BHT07,,165,1,0,0,0,0,0,1521763200
# 6207089.068,15-04-18, 4 ,DPI66285_43205_421,303,NVPARCEL,PNVG01,,39,0,0,0,0,1,0,1523750400
# 6207089.068,15-04-18, 4 ,DPI66285_43205_421,303,PIZ0133,FP07,,120,0,1,0,0,0,0,1523750400
# 6207089.068,15-04-18, 4 ,DPI66285_43205_421,303,VGPARCEL,PVEG01,,35,0,0,0,0,1,0,1523750400

# %%
import sagemaker
import sagemaker.amazon.common as smac
from sagemaker import get_execution_role
from sagemaker.predictor import json_deserializer

import boto3, csv, io, json
import numpy as np
from scipy.sparse import lil_matrix

import pandas as pd
from sklearn.model_selection import train_test_split

import datetime
from dateutil.parser import parse

# %% [markdown]
# ## Load data
#
# Check how man

# %%
df = pd.read_csv("UpdatedOLOdata.csv", usecols=[0,1,5]) 
df = df[df.OrderDate == df.OrderDate]
df = df[df.OrderDate != '4-Feb-18']
movie_dict = dict([(y,x+1) for x,y in enumerate(sorted(set(df['MenuCode'])))])
user_dict = dict([(y,x+1) for x,y in enumerate(sorted(set(df['UserID'])))])
user_reverse_dict = dict([(x+1,y) for x,y in enumerate(sorted(set(df['UserID'])))])
movie_reverse_dict = dict([(x+1, y) for x,y in enumerate(sorted(set(df['MenuCode'])))])

#idx = df.index[df['OrderDate'] == 'nan'].tolist()
#idx = df[df['OrderDate'].isnull()]

print(df.isnull().any().any())

#df['OrderDate'] = [parse(str(x)) for x in df['OrderDate']]

#d['PIZ0100']
df['MenuCode'] = df['MenuCode'].apply(lambda x: int(movie_dict[str(x)]))
df['UserID'] = df['UserID'].apply(lambda x: int(user_dict[float(x)]))
df['DayOfWeek'] = df['OrderDate'].apply(lambda x: datetime.datetime.strptime(x, "%d-%m-%y").date().weekday())
df['WeekOfYear'] = df['OrderDate'].apply(lambda x: datetime.datetime.strptime(x, "%d-%m-%y").date().isocalendar()[1])
#df

df_g = df.groupby(['UserID', 'MenuCode', 'WeekOfYear']).size().reset_index(name='count')

df_g[df_g['count'] >2]
# Out:
# False
#         UserID  MenuCode  WeekOfYear  count
# 94           8        36          14      3
# 95           8        36          15      3
# 96           8        36          16      3
# 97           8        36          17      4
# 98           8        36          18      3
# 127          8       115          19      3
# 312         15        36          10      3
# 318         15        83          12      4
# 416         19        36          23      3
# 430         20        13          15      3
# 447         20       112          15      3
# 578         32        36           5      7
# 586         32        36          25      3
# 714         40         1           5      5
# 716         40         1           7      4
# 726         40        37           5      3
# 728         40        37           7      3
# 732         40       110           5      3
# 734         40       110           7      4
# 946         50        37          18      3
# 955         50        47          18      5
# 965         50        72          18      4
# 967         50        72          20      3
# 968         50        72          21      3
# 972         50        79          19      3
# 993         51        10          12      3
# 1002        51        21          12      3
# 1122        55       109           4      3
# 1383        71        36           3      3
# 1405        74         2          15      4
# ...        ...       ...         ...    ...
# 338785   14717        10          22      3
# 338786   14717        10          24      3
# 338788   14717        11          22      3
# 338820   14717        73          22      3
# 338827   14717        88          29      3
# 338828   14717        88          30      4
# 339054   14727         9          22      3
# 339092   14727        78          22      3
# 339227   14734        48          11      3
# 339413   14741         1          20      3
# 339446   14741        42          20      5
# 339448   14741        42          22      3
# 339664   14753        96          14      3
# 339790   14756        18          10      3
# 340338   14789        72          16      3
# 340489   14796        32           9      3
# 340506   14797        48          21      3
# 340509   14797        49          21      4
# 340549   14800         3          15      3
# 340552   14800         3          18      5
# 340553   14800         3          19      3
# 340556   14800         3          22      4
# 340557   14800         3          23      4
# 340560   14800         3          28      5
# 340579   14800         9          28      3
# 340605   14800        36          15      3
# 340611   14800        36          22      4
# 340626   14800        44          18      3
# 340634   14800        44          28      5
# 340751   14804        71          16      3
#
# [4995 rows x 4 columns]

# %%
numberOfUsers=len(df['UserID'].unique().tolist())
numberOfMenuItems=len(df['MenuCode'].unique().tolist())
numFeatures = numberOfUsers + numberOfMenuItems
print(numberOfUsers)
print(numberOfMenuItems)
print(len(df))
# Out:
# 14813
# 115
# 379187

# %% [markdown]
# ## Add Rating into data set
# Rating Assumption:
# If a customer has eaten once but not repeated a pizza (count <2) then she didnt like it.

# %%
#df['MenuCode'] = df['MenuCode'].apply(lambda x: int(movie_dict[str(x)]))
#df['UserID'] = df['UserID'].apply(lambda x: int(user_dict[float(x)]))

df_g = df.groupby(['UserID', 'MenuCode']).size().reset_index(name='count')

df_g[df_g['count'] >1]

df_g['rating'] = df_g['count'].apply(lambda x: 1 if x>1 else 0)

print('Rating 1 : {}'.format(df_g[df_g['rating']==1].count()))
print('Rating 0 : {}'.format(df_g[df_g['rating']==0].count()))
# Out:
# Rating 1 : UserID      27643
# MenuCode    27643
# count       27643
# rating      27643
# dtype: int64
# Rating 0 : UserID      120024
# MenuCode    120024
# count       120024
# rating      120024
# dtype: int64

# %% [markdown]
# ## Downsampling the  data to reduce Label 0

# %%
df = df_g.drop('count', axis=1)
print(df.shape)
df = df.drop(df.query('rating == 0').sample(frac=.5).index)
print(df.shape)
print('Rating 1 : {}'.format(df[df['rating']==1].count()))
print('Rating 0 : {}'.format(df[df['rating']==0].count()))
# Out:
# (147667, 3)
# (87655, 3)
# Rating 1 : UserID      27643
# MenuCode    27643
# rating      27643
# dtype: int64
# Rating 0 : UserID      60012
# MenuCode    60012
# rating      60012
# dtype: int64

# %% [markdown]
# ### Spilt into test and train

# %%
train, test = train_test_split(df, test_size=0.2)
numberOfRowsTrain = len(train)
numberOfRowsTest = len(test)
print(numberOfRowsTrain,numberOfRowsTest)
print(train[2:5])
# Out:
# (70124, 17531)
#         UserID  MenuCode  rating
# 107162   10681       114       1
# 93218     9287        38       0
# 42784     4220        78       0

# %% [markdown]
# ## One-hot encode the data
# [user1,user2,...,user n, menu1, menu2, ..., menu n]
#
# [1,0,0,...,0,0,1,0,...,0]

# %%
#Do OneHot Encoding
def loadDataset(dfname, lines, columns):
    # Features are one-hot encoded in a sparse matrix
    X = lil_matrix((lines, columns)).astype('float32')
    # Labels are stored in a vector
    Y = []
    line=0
    for userId, menuCode, rating in dfname.values:
        X[line,userId] = 1
        X[line,int(numberOfUsers)+int(menuCode)-1] = 1
        Y.append(rating)
        line=line+1
            
    Y=np.array(Y).astype('float32')
    #print (X,Y)
    return X,Y

# %%
X_train, Y_train = loadDataset(train,numberOfRowsTrain,numFeatures)
X_test, Y_test = loadDataset(test,numberOfRowsTest,numFeatures)

# %%
print(X_train.shape)
print(Y_train.shape)
assert X_train.shape == (numberOfRowsTrain, numFeatures)
assert Y_train.shape == (numberOfRowsTrain, )
non_zero_labels = np.count_nonzero(Y_train)
print("Training labels: %d zeros, %d ones" % (numberOfRowsTrain-non_zero_labels, non_zero_labels))

print(X_test.shape)
print(Y_test.shape)
assert X_test.shape  == (numberOfRowsTest, numFeatures)
assert Y_test.shape  == (numberOfRowsTest, )
zero_labels = np.count_nonzero(Y_test)
print("Test labels: %d zeros, %d ones" % (numberOfRowsTest-zero_labels, zero_labels))
# Out:
# (118133, 14928)
# (118133,)
# Training labels: 114747 zeros, 3386 ones
# (29534, 14928)
# (29534,)
# Test labels: 28677 zeros, 857 ones

# %%
print(train.values[1])
print(X_train[1])
print(train.values[2])
print(X_train[2])
# Out:
# [9937    6]
#   (0, 9937)	1.0
#   (0, 14819)	1.0
# [10018    11]
#   (0, 10018)	1.0
#   (0, 14824)	1.0

# %% [markdown]
# ### Convert to protobuf and save to S3

# %%
bucket = 'ar-sm-bucket'
prefix = 'Jubilant'

train_key      = 'train.protobuf'
train_prefix   = '{}/{}'.format(prefix, 'train3')

test_key       = 'test.protobuf'
test_prefix    = '{}/{}'.format(prefix, 'test3')

output_prefix  = 's3://{}/{}/output'.format(bucket, prefix)
print(output_prefix)
# Out:
# s3://ar-sm-bucket/Jubilant/output

# %%
def writeDatasetToProtobuf(X, Y, bucket, prefix, key):
    buf = io.BytesIO()
    smac.write_spmatrix_to_sparse_tensor(buf, X, Y)
    buf.seek(0)
    obj = '{}/{}'.format(prefix, key)
    boto3.resource('s3').Bucket(bucket).Object(obj).upload_fileobj(buf)
    return 's3://{}/{}'.format(bucket,obj)
    
train_data = writeDatasetToProtobuf(X_train, Y_train, bucket, train_prefix, train_key)    
test_data  = writeDatasetToProtobuf(X_test, Y_test, bucket, test_prefix, test_key)    
  
print(train_data)
print(test_data)
print('Output: {}'.format(output_prefix))
# Out:
# s3://ar-sm-bucket/Jubilant/train3/train.protobuf
# s3://ar-sm-bucket/Jubilant/test3/test.protobuf
# Output: s3://ar-sm-bucket/Jubilant/output

# %% [markdown]
# ### Run training job

# %%
containers = {'us-west-2': '174872318107.dkr.ecr.us-west-2.amazonaws.com/factorization-machines:latest',
              'us-east-1': '382416733822.dkr.ecr.us-east-1.amazonaws.com/factorization-machines:latest',
              'us-east-2': '404615174143.dkr.ecr.us-east-2.amazonaws.com/factorization-machines:latest',
              'eu-west-1': '438346466558.dkr.ecr.eu-west-1.amazonaws.com/factorization-machines:latest'}

# %%
fm = sagemaker.estimator.Estimator(containers[boto3.Session().region_name],
                                   get_execution_role(), 
                                   train_instance_count=1, 
                                   train_instance_type='ml.c4.xlarge',
                                   output_path=output_prefix,
                                   sagemaker_session=sagemaker.Session())

fm.set_hyperparameters(feature_dim=numFeatures,
                      predictor_type='binary_classifier',
                      mini_batch_size=1000,
                      num_factors=64,
                      epochs=100)

fm.fit({'train': train_data, 'test': test_data})
# Out:
# INFO:sagemaker:Creating training-job with name: factorization-machines-2018-09-18-11-27-58-824
# ....................
# Docker entrypoint called with argument(s): train
# [09/18/2018 11:31:09 INFO 139994573981504] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-conf.json: {u'factors_lr': u'0.0001', u'linear_init_sigma': u'0.01', u'epochs': 1, u'_wd': u'1.0', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'factors_init_sigma': u'0.001', u'_log_level': u'info', u'bias_init_method': u'normal', u'linear_init_method': u'normal', u'linear_lr': u'0.001', u'factors_init_method': u'normal', u'_tuning_objective_metric': u'', u'bias_wd': u'0.01', u'use_linear': u'true', u'bias_lr': u'0.1', u'mini_batch_size': u'1000', u'_use_full_symbolic': u'true', u'batch_metrics_publish_interval': u'500', u'bias_init_sigma': u'0.01', u'_num_gpus': u'auto', u'_data_format': u'record', u'factors_wd': u'0.00001', u'linear_wd': u'0.001', u'_kvstore': u'auto', u'_learning_rate': u'1.0', u'_optimizer': u'adam'}
# [09/18/2018 11:31:09 INFO 139994573981504] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'epochs': u'100', u'feature_dim': u'14928', u'mini_batch_size': u'1000', u'predictor_type': u'binary_classifier', u'num_factors': u'64'}
# [09/18/2018 11:31:09 INFO 139994573981504] Final configuration: {u'factors_lr': u'0.0001', u'linear_init_sigma': u'0.01', u'epochs': u'100', u'feature_dim': u'14928', u'num_factors': u'64', u'_wd': u'1.0', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'factors_init_sigma': u'0.001', u'_log_level': u'info', u'bias_init_method': u'normal', u'linear_init_method': u'normal', u'linear_lr': u'0.001', u'factors_init_method': u'normal', u'_tuning_objective_metric': u'', u'bias_wd': u'0.01', u'use_linear': u'true', u'bias_lr': u'0.1', u'mini_batch_size': u'1000', u'_use_full_symbolic': u'true', u'batch_metrics_publish_interval': u'500', u'predictor_type': u'binary_classifier', u'bias_init_sigma': u'0.01', u'_num_gpus': u'auto', u'_data_format': u'record', u'factors_wd': u'0.00001', u'linear_wd': u'0.001', u'_kvstore': u'auto', u'_learning_rate': u'1.0', u'_optimizer': u'adam'}
# [09/18/2018 11:31:09 WARNING 139994573981504] Loggers have already been setup.
# [09/18/2018 11:31:09 INFO 139994573981504] Using default worker.
# [09/18/2018 11:31:09 INFO 139994573981504] nvidia-smi took: 0.0251729488373 secs to identify 0 gpus
# [09/18/2018 11:31:09 INFO 139994573981504] Number of GPUs being used: 0
# [09/18/2018 11:31:09 INFO 139994573981504] [Sparse network] Building a sparse network.
# [09/18/2018 11:31:09 INFO 139994573981504] Create Store: local
# #metrics {"Metrics": {"initialize.time": {"count": 1, "max": 37.019968032836914, "sum": 37.019968032836914, "min": 37.019968032836914}}, "EndTime": 1537270269.788525, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1537270269.725145}
#
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Total Records Seen": {"count": 1, "max": 1000, "sum": 1000.0, "min": 1000}, "Max Records Seen Between Resets": {"count": 1, "max": 1000, "sum": 1000.0, "min": 1000}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1537270269.78873, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1537270269.788679}
#
# [11:31:09] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.1.x.200686.0/RHEL5_64/generic-flavor/src/src/kvstore/./kvstore_local.h:280: Warning: non-default weights detected during kvstore pull. This call has been ignored. Please make sure to use row_sparse_pull with row_ids.
# [11:31:09] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.1.x.200686.0/RHEL5_64/generic-flavor/src/src/kvstore/./kvstore_local.h:280: Warning: non-default weights detected during kvstore pull. This call has been ignored. Please make sure to use row_sparse_pull with row_ids.
# [09/18/2018 11:31:09 INFO 139994573981504] #quality_metric: host=algo-1, epoch=0, batch=0 train binary_classification_accuracy <score>=0.368
# [09/18/2018 11:31:09 INFO 139994573981504] #quality_metric: host=algo-1, epoch=0, batch=0 train binary_classification_cross_entropy <loss>=0.696489990234
# [09/18/2018 11:31:09 INFO 139994573981504] #quality_metric: host=algo-1, epoch=0, batch=0 train binary_f_1.000 <score>=0.519756838906
# [09/18/2018 11:31:10 INFO 139994573981504] #quality_metric: host=algo-1, epoch=0, train binary_classification_accuracy <score>=0.683845070423
# [09/18/2018 11:31:10 INFO 139994573981504] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy <loss>=0.622256523025
# [09/18/2018 11:31:10 INFO 139994573981504] #quality_metric: host=algo-1, epoch=0, train binary_f_1.000 <score>=0.029570705979
# #metrics {"Metrics": {"epochs": {"count": 1, "max": 100, "sum": 100.0, "min": 100}, "update.time": {"count": 1, "max": 717.50807762146, "sum": 717.50807762146, "min": 717.50807762146}}, "EndTime": 1537270270.506537, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1537270269.788616}
#
# [09/18/2018 11:31:10 INFO 139994573981504] #progress_metric: host=algo-1, completed 1 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Total Batches Seen": {"count": 1, "max": 72, "sum": 72.0, "min": 72}, "Total Records Seen": {"count": 1, "max": 71124, "sum": 71124.0, "min": 71124}, "Max Records Seen Between Resets": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1537270270.506751, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 0}, "StartTime": 1537270269.789001}
#
# [09/18/2018 11:31:10 INFO 139994573981504] #throughput_metric: host=algo-1, train throughput=97684.106279 records/second
# [09/18/2018 11:31:10 INFO 139994573981504] #quality_metric: host=algo-1, epoch=1, batch=0 train binary_classification_accuracy <score>=0.648
# [09/18/2018 11:31:10 INFO 139994573981504] #quality_metric: host=algo-1, epoch=1, batch=0 train binary_classification_cross_entropy <loss>=0.647706054687
# [09/18/2018 11:31:10 INFO 139994573981504] #quality_metric: host=algo-1, epoch=1, batch=0 train binary_f_1.000 <score>=0.0
# [09/18/2018 11:31:11 INFO 139994573981504] #quality_metric: host=algo-1, epoch=1, train binary_classification_accuracy <score>=0.687788732394
# [09/18/2018 11:31:11 INFO 139994573981504] #quality_metric: host=algo-1, epoch=1, train binary_classification_cross_entropy <loss>=0.614351384123
# [09/18/2018 11:31:11 INFO 139994573981504] #quality_metric: host=algo-1, epoch=1, train binary_f_1.000 <score>=0.0
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 554.4590950012207, "sum": 554.4590950012207, "min": 554.4590950012207}}, "EndTime": 1537270271.061539, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1537270270.506609}
#
# [09/18/2018 11:31:11 INFO 139994573981504] #progress_metric: host=algo-1, completed 2 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Total Batches Seen": {"count": 1, "max": 143, "sum": 143.0, "min": 143}, "Total Records Seen": {"count": 1, "max": 141248, "sum": 141248.0, "min": 141248}, "Max Records Seen Between Resets": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1537270271.061816, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 1}, "StartTime": 1537270270.507051}
#
# [09/18/2018 11:31:11 INFO 139994573981504] #throughput_metric: host=algo-1, train throughput=126375.701577 records/second
# [09/18/2018 11:31:11 INFO 139994573981504] #quality_metric: host=algo-1, epoch=2, batch=0 train binary_classification_accuracy <score>=0.648
# [09/18/2018 11:31:11 INFO 139994573981504] #quality_metric: host=algo-1, epoch=2, batch=0 train binary_classification_cross_entropy <loss>=0.641897216797
# [09/18/2018 11:31:11 INFO 139994573981504] #quality_metric: host=algo-1, epoch=2, batch=0 train binary_f_1.000 <score>=0.0
# [09/18/2018 11:31:11 INFO 139994573981504] #quality_metric: host=algo-1, epoch=2, train binary_classification_accuracy <score>=0.687788732394
# [09/18/2018 11:31:11 INFO 139994573981504] #quality_metric: host=algo-1, epoch=2, train binary_classification_cross_entropy <loss>=0.609427431348
# [09/18/2018 11:31:11 INFO 139994573981504] #quality_metric: host=algo-1, epoch=2, train binary_f_1.000 <score>=0.0
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 587.6238346099854, "sum": 587.6238346099854, "min": 587.6238346099854}}, "EndTime": 1537270271.649791, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1537270271.061672}
#
# [09/18/2018 11:31:11 INFO 139994573981504] #progress_metric: host=algo-1, completed 3 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Total Batches Seen": {"count": 1, "max": 214, "sum": 214.0, "min": 214}, "Total Records Seen": {"count": 1, "max": 211372, "sum": 211372.0, "min": 211372}, "Max Records Seen Between Resets": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1537270271.649991, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 2}, "StartTime": 1537270271.062141}
#
# [09/18/2018 11:31:11 INFO 139994573981504] #throughput_metric: host=algo-1, train throughput=119267.631429 records/second
# [09/18/2018 11:31:11 INFO 139994573981504] #quality_metric: host=algo-1, epoch=3, batch=0 train binary_classification_accuracy <score>=0.648
# [09/18/2018 11:31:11 INFO 139994573981504] #quality_metric: host=algo-1, epoch=3, batch=0 train binary_classification_cross_entropy <loss>=0.636367126465
# [09/18/2018 11:31:11 INFO 139994573981504] #quality_metric: host=algo-1, epoch=3, batch=0 train binary_f_1.000 <score>=0.0
# [09/18/2018 11:31:12 INFO 139994573981504] #quality_metric: host=algo-1, epoch=3, train binary_classification_accuracy <score>=0.687788732394
# [09/18/2018 11:31:12 INFO 139994573981504] #quality_metric: host=algo-1, epoch=3, train binary_classification_cross_entropy <loss>=0.604658033774
# [09/18/2018 11:31:12 INFO 139994573981504] #quality_metric: host=algo-1, epoch=3, train binary_f_1.000 <score>=0.0
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 545.6438064575195, "sum": 545.6438064575195, "min": 545.6438064575195}}, "EndTime": 1537270272.195959, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1537270271.649847}
#
# [09/18/2018 11:31:12 INFO 139994573981504] #progress_metric: host=algo-1, completed 4 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Total Batches Seen": {"count": 1, "max": 285, "sum": 285.0, "min": 285}, "Total Records Seen": {"count": 1, "max": 281496, "sum": 281496.0, "min": 281496}, "Max Records Seen Between Resets": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1537270272.19623, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 3}, "StartTime": 1537270271.650287}
#
# [09/18/2018 11:31:12 INFO 139994573981504] #throughput_metric: host=algo-1, train throughput=128416.476499 records/second
# [09/18/2018 11:31:12 INFO 139994573981504] #quality_metric: host=algo-1, epoch=4, batch=0 train binary_classification_accuracy <score>=0.648
# [09/18/2018 11:31:12 INFO 139994573981504] #quality_metric: host=algo-1, epoch=4, batch=0 train binary_classification_cross_entropy <loss>=0.63108581543
# [09/18/2018 11:31:12 INFO 139994573981504] #quality_metric: host=algo-1, epoch=4, batch=0 train binary_f_1.000 <score>=0.0
# [09/18/2018 11:31:12 INFO 139994573981504] #quality_metric: host=algo-1, epoch=4, train binary_classification_accuracy <score>=0.687788732394
# [09/18/2018 11:31:12 INFO 139994573981504] #quality_metric: host=algo-1, epoch=4, train binary_classification_cross_entropy <loss>=0.600028631506
# [09/18/2018 11:31:12 INFO 139994573981504] #quality_metric: host=algo-1, epoch=4, train binary_f_1.000 <score>=0.0
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 585.2558612823486, "sum": 585.2558612823486, "min": 585.2558612823486}}, "EndTime": 1537270272.781824, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1537270272.196083}
#
# [09/18/2018 11:31:12 INFO 139994573981504] #progress_metric: host=algo-1, completed 5 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Total Batches Seen": {"count": 1, "max": 356, "sum": 356.0, "min": 356}, "Total Records Seen": {"count": 1, "max": 351620, "sum": 351620.0, "min": 351620}, "Max Records Seen Between Resets": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Reset Count": {"count": 1, "max": 6, "sum": 6.0, "min": 6}}, "EndTime": 1537270272.782022, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 4}, "StartTime": 1537270272.196541}
#
# [09/18/2018 11:31:12 INFO 139994573981504] #throughput_metric: host=algo-1, train throughput=119744.363221 records/second
# [09/18/2018 11:31:12 INFO 139994573981504] #quality_metric: host=algo-1, epoch=5, batch=0 train binary_classification_accuracy <score>=0.648
# [09/18/2018 11:31:12 INFO 139994573981504] #quality_metric: host=algo-1, epoch=5, batch=0 train binary_classification_cross_entropy <loss>=0.625991149902
# [09/18/2018 11:31:12 INFO 139994573981504] #quality_metric: host=algo-1, epoch=5, batch=0 train binary_f_1.000 <score>=0.0
# [09/18/2018 11:31:13 INFO 139994573981504] #quality_metric: host=algo-1, epoch=5, train binary_classification_accuracy <score>=0.687788732394
# [09/18/2018 11:31:13 INFO 139994573981504] #quality_metric: host=algo-1, epoch=5, train binary_classification_cross_entropy <loss>=0.595527715978
# [09/18/2018 11:31:13 INFO 139994573981504] #quality_metric: host=algo-1, epoch=5, train binary_f_1.000 <score>=0.0
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 544.1069602966309, "sum": 544.1069602966309, "min": 544.1069602966309}}, "EndTime": 1537270273.326432, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1537270272.781887}
#
# [09/18/2018 11:31:13 INFO 139994573981504] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Total Batches Seen": {"count": 1, "max": 427, "sum": 427.0, "min": 427}, "Total Records Seen": {"count": 1, "max": 421744, "sum": 421744.0, "min": 421744}, "Max Records Seen Between Resets": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Reset Count": {"count": 1, "max": 7, "sum": 7.0, "min": 7}}, "EndTime": 1537270273.326631, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 5}, "StartTime": 1537270272.782292}
#
# [09/18/2018 11:31:13 INFO 139994573981504] #throughput_metric: host=algo-1, train throughput=128794.587647 records/second
# [09/18/2018 11:31:13 INFO 139994573981504] #quality_metric: host=algo-1, epoch=6, batch=0 train binary_classification_accuracy <score>=0.648
# [09/18/2018 11:31:13 INFO 139994573981504] #quality_metric: host=algo-1, epoch=6, batch=0 train binary_classification_cross_entropy <loss>=0.621042541504
# [09/18/2018 11:31:13 INFO 139994573981504] #quality_metric: host=algo-1, epoch=6, batch=0 train binary_f_1.000 <score>=0.0
# [09/18/2018 11:31:13 INFO 139994573981504] #quality_metric: host=algo-1, epoch=6, train binary_classification_accuracy <score>=0.687788732394
# [09/18/2018 11:31:13 INFO 139994573981504] #quality_metric: host=algo-1, epoch=6, train binary_classification_cross_entropy <loss>=0.591129044224
# [09/18/2018 11:31:13 INFO 139994573981504] #quality_metric: host=algo-1, epoch=6, train binary_f_1.000 <score>=0.0
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 583.8451385498047, "sum": 583.8451385498047, "min": 583.8451385498047}}, "EndTime": 1537270273.910794, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1537270273.326497}
#
# [09/18/2018 11:31:13 INFO 139994573981504] #progress_metric: host=algo-1, completed 7 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Total Batches Seen": {"count": 1, "max": 498, "sum": 498.0, "min": 498}, "Total Records Seen": {"count": 1, "max": 491868, "sum": 491868.0, "min": 491868}, "Max Records Seen Between Resets": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Reset Count": {"count": 1, "max": 8, "sum": 8.0, "min": 8}}, "EndTime": 1537270273.910987, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 6}, "StartTime": 1537270273.326921}
#
# [09/18/2018 11:31:13 INFO 139994573981504] #throughput_metric: host=algo-1, train throughput=120038.124413 records/second
# [09/18/2018 11:31:13 INFO 139994573981504] #quality_metric: host=algo-1, epoch=7, batch=0 train binary_classification_accuracy <score>=0.648
# [09/18/2018 11:31:13 INFO 139994573981504] #quality_metric: host=algo-1, epoch=7, batch=0 train binary_classification_cross_entropy <loss>=0.616204101563
# [09/18/2018 11:31:13 INFO 139994573981504] #quality_metric: host=algo-1, epoch=7, batch=0 train binary_f_1.000 <score>=0.0
# [09/18/2018 11:31:14 INFO 139994573981504] #quality_metric: host=algo-1, epoch=7, train binary_classification_accuracy <score>=0.687788732394
# [09/18/2018 11:31:14 INFO 139994573981504] #quality_metric: host=algo-1, epoch=7, train binary_classification_cross_entropy <loss>=0.586804761
# [09/18/2018 11:31:14 INFO 139994573981504] #quality_metric: host=algo-1, epoch=7, train binary_f_1.000 <score>=0.0
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 556.6129684448242, "sum": 556.6129684448242, "min": 556.6129684448242}}, "EndTime": 1537270274.467901, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1537270273.910855}
#
# [09/18/2018 11:31:14 INFO 139994573981504] #progress_metric: host=algo-1, completed 8 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Total Batches Seen": {"count": 1, "max": 569, "sum": 569.0, "min": 569}, "Total Records Seen": {"count": 1, "max": 561992, "sum": 561992.0, "min": 561992}, "Max Records Seen Between Resets": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Reset Count": {"count": 1, "max": 9, "sum": 9.0, "min": 9}}, "EndTime": 1537270274.468125, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 7}, "StartTime": 1537270273.911259}
#
# [09/18/2018 11:31:14 INFO 139994573981504] #throughput_metric: host=algo-1, train throughput=125898.582897 records/second
# [09/18/2018 11:31:14 INFO 139994573981504] #quality_metric: host=algo-1, epoch=8, batch=0 train binary_classification_accuracy <score>=0.648
# [09/18/2018 11:31:14 INFO 139994573981504] #quality_metric: host=algo-1, epoch=8, batch=0 train binary_classification_cross_entropy <loss>=0.611444458008
# [09/18/2018 11:31:14 INFO 139994573981504] #quality_metric: host=algo-1, epoch=8, batch=0 train binary_f_1.000 <score>=0.0
# [09/18/2018 11:31:15 INFO 139994573981504] #quality_metric: host=algo-1, epoch=8, train binary_classification_accuracy <score>=0.687788732394
# [09/18/2018 11:31:15 INFO 139994573981504] #quality_metric: host=algo-1, epoch=8, train binary_classification_cross_entropy <loss>=0.582529600761
# [09/18/2018 11:31:15 INFO 139994573981504] #quality_metric: host=algo-1, epoch=8, train binary_f_1.000 <score>=0.0
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 574.4960308074951, "sum": 574.4960308074951, "min": 574.4960308074951}}, "EndTime": 1537270275.04296, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1537270274.467971}
#
# [09/18/2018 11:31:15 INFO 139994573981504] #progress_metric: host=algo-1, completed 9 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Total Batches Seen": {"count": 1, "max": 640, "sum": 640.0, "min": 640}, "Total Records Seen": {"count": 1, "max": 632116, "sum": 632116.0, "min": 632116}, "Max Records Seen Between Resets": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Reset Count": {"count": 1, "max": 10, "sum": 10.0, "min": 10}}, "EndTime": 1537270275.043197, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 8}, "StartTime": 1537270274.468433}
#
# [09/18/2018 11:31:15 INFO 139994573981504] #throughput_metric: host=algo-1, train throughput=121979.808519 records/second
# [09/18/2018 11:31:15 INFO 139994573981504] #quality_metric: host=algo-1, epoch=9, batch=0 train binary_classification_accuracy <score>=0.648
# [09/18/2018 11:31:15 INFO 139994573981504] #quality_metric: host=algo-1, epoch=9, batch=0 train binary_classification_cross_entropy <loss>=0.606736938477
# [09/18/2018 11:31:15 INFO 139994573981504] #quality_metric: host=algo-1, epoch=9, batch=0 train binary_f_1.000 <score>=0.0
# [09/18/2018 11:31:15 INFO 139994573981504] #quality_metric: host=algo-1, epoch=9, train binary_classification_accuracy <score>=0.687915492958
# [09/18/2018 11:31:15 INFO 139994573981504] #quality_metric: host=algo-1, epoch=9, train binary_classification_cross_entropy <loss>=0.578282147905
# [09/18/2018 11:31:15 INFO 139994573981504] #quality_metric: host=algo-1, epoch=9, train binary_f_1.000 <score>=0.000811688311688
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 568.7921047210693, "sum": 568.7921047210693, "min": 568.7921047210693}}, "EndTime": 1537270275.612346, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1537270275.043033}
#
# [09/18/2018 11:31:15 INFO 139994573981504] #progress_metric: host=algo-1, completed 10 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Total Batches Seen": {"count": 1, "max": 711, "sum": 711.0, "min": 711}, "Total Records Seen": {"count": 1, "max": 702240, "sum": 702240.0, "min": 702240}, "Max Records Seen Between Resets": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Reset Count": {"count": 1, "max": 11, "sum": 11.0, "min": 11}}, "EndTime": 1537270275.612561, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 9}, "StartTime": 1537270275.043521}
#
# [09/18/2018 11:31:15 INFO 139994573981504] #throughput_metric: host=algo-1, train throughput=123202.467429 records/second
# [09/18/2018 11:31:15 INFO 139994573981504] #quality_metric: host=algo-1, epoch=10, batch=0 train binary_classification_accuracy <score>=0.648
# [09/18/2018 11:31:15 INFO 139994573981504] #quality_metric: host=algo-1, epoch=10, batch=0 train binary_classification_cross_entropy <loss>=0.602059875488
# [09/18/2018 11:31:15 INFO 139994573981504] #quality_metric: host=algo-1, epoch=10, batch=0 train binary_f_1.000 <score>=0.0
# [09/18/2018 11:31:16 INFO 139994573981504] #quality_metric: host=algo-1, epoch=10, train binary_classification_accuracy <score>=0.689084507042
# [09/18/2018 11:31:16 INFO 139994573981504] #quality_metric: host=algo-1, epoch=10, train binary_classification_cross_entropy <loss>=0.574044949384
# [09/18/2018 11:31:16 INFO 139994573981504] #quality_metric: host=algo-1, epoch=10, train binary_f_1.000 <score>=0.00835541979246
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 584.3110084533691, "sum": 584.3110084533691, "min": 584.3110084533691}}, "EndTime": 1537270276.197203, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1537270275.612399}
#
# [09/18/2018 11:31:16 INFO 139994573981504] #progress_metric: host=algo-1, completed 11 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Total Batches Seen": {"count": 1, "max": 782, "sum": 782.0, "min": 782}, "Total Records Seen": {"count": 1, "max": 772364, "sum": 772364.0, "min": 772364}, "Max Records Seen Between Resets": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Reset Count": {"count": 1, "max": 12, "sum": 12.0, "min": 12}}, "EndTime": 1537270276.197415, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 10}, "StartTime": 1537270275.612861}
#
# [09/18/2018 11:31:16 INFO 139994573981504] #throughput_metric: host=algo-1, train throughput=119935.870451 records/second
# [09/18/2018 11:31:16 INFO 139994573981504] #quality_metric: host=algo-1, epoch=11, batch=0 train binary_classification_accuracy <score>=0.648
# [09/18/2018 11:31:16 INFO 139994573981504] #quality_metric: host=algo-1, epoch=11, batch=0 train binary_classification_cross_entropy <loss>=0.597395385742
# [09/18/2018 11:31:16 INFO 139994573981504] #quality_metric: host=algo-1, epoch=11, batch=0 train binary_f_1.000 <score>=0.0
# [09/18/2018 11:31:16 INFO 139994573981504] #quality_metric: host=algo-1, epoch=11, train binary_classification_accuracy <score>=0.692971830986
# [09/18/2018 11:31:16 INFO 139994573981504] #quality_metric: host=algo-1, epoch=11, train binary_classification_cross_entropy <loss>=0.56980421985
# [09/18/2018 11:31:16 INFO 139994573981504] #quality_metric: host=algo-1, epoch=11, train binary_f_1.000 <score>=0.0330035931331
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 593.6801433563232, "sum": 593.6801433563232, "min": 593.6801433563232}}, "EndTime": 1537270276.791436, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1537270276.197268}
#
# [09/18/2018 11:31:16 INFO 139994573981504] #progress_metric: host=algo-1, completed 12 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Total Batches Seen": {"count": 1, "max": 853, "sum": 853.0, "min": 853}, "Total Records Seen": {"count": 1, "max": 842488, "sum": 842488.0, "min": 842488}, "Max Records Seen Between Resets": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Reset Count": {"count": 1, "max": 13, "sum": 13.0, "min": 13}}, "EndTime": 1537270276.791641, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 11}, "StartTime": 1537270276.197725}
#
# [09/18/2018 11:31:16 INFO 139994573981504] #throughput_metric: host=algo-1, train throughput=118049.492776 records/second
# [09/18/2018 11:31:16 INFO 139994573981504] #quality_metric: host=algo-1, epoch=12, batch=0 train binary_classification_accuracy <score>=0.649
# [09/18/2018 11:31:16 INFO 139994573981504] #quality_metric: host=algo-1, epoch=12, batch=0 train binary_classification_cross_entropy <loss>=0.592729614258
# [09/18/2018 11:31:16 INFO 139994573981504] #quality_metric: host=algo-1, epoch=12, batch=0 train binary_f_1.000 <score>=0.0056657223796
# [09/18/2018 11:31:17 INFO 139994573981504] #quality_metric: host=algo-1, epoch=12, train binary_classification_accuracy <score>=0.698943661972
# [09/18/2018 11:31:17 INFO 139994573981504] #quality_metric: host=algo-1, epoch=12, train binary_classification_cross_entropy <loss>=0.565549411398
# [09/18/2018 11:31:17 INFO 139994573981504] #quality_metric: host=algo-1, epoch=12, train binary_f_1.000 <score>=0.0701265932919
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 535.4349613189697, "sum": 535.4349613189697, "min": 535.4349613189697}}, "EndTime": 1537270277.327398, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1537270276.791513}
#
# [09/18/2018 11:31:17 INFO 139994573981504] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Total Batches Seen": {"count": 1, "max": 924, "sum": 924.0, "min": 924}, "Total Records Seen": {"count": 1, "max": 912612, "sum": 912612.0, "min": 912612}, "Max Records Seen Between Resets": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Reset Count": {"count": 1, "max": 14, "sum": 14.0, "min": 14}}, "EndTime": 1537270277.327601, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 12}, "StartTime": 1537270276.791932}
#
# [09/18/2018 11:31:17 INFO 139994573981504] #throughput_metric: host=algo-1, train throughput=130878.653777 records/second
# [09/18/2018 11:31:17 INFO 139994573981504] #quality_metric: host=algo-1, epoch=13, batch=0 train binary_classification_accuracy <score>=0.649
# [09/18/2018 11:31:17 INFO 139994573981504] #quality_metric: host=algo-1, epoch=13, batch=0 train binary_classification_cross_entropy <loss>=0.588051818848
# [09/18/2018 11:31:17 INFO 139994573981504] #quality_metric: host=algo-1, epoch=13, batch=0 train binary_f_1.000 <score>=0.0056657223796
# [09/18/2018 11:31:17 INFO 139994573981504] #quality_metric: host=algo-1, epoch=13, train binary_classification_accuracy <score>=0.706225352113
# [09/18/2018 11:31:17 INFO 139994573981504] #quality_metric: host=algo-1, epoch=13, train binary_classification_cross_entropy <loss>=0.56127275021
# [09/18/2018 11:31:17 INFO 139994573981504] #quality_metric: host=algo-1, epoch=13, train binary_f_1.000 <score>=0.113406443934
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 550.4038333892822, "sum": 550.4038333892822, "min": 550.4038333892822}}, "EndTime": 1537270277.878297, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1537270277.327464}
#
# [09/18/2018 11:31:17 INFO 139994573981504] #progress_metric: host=algo-1, completed 14 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Total Batches Seen": {"count": 1, "max": 995, "sum": 995.0, "min": 995}, "Total Records Seen": {"count": 1, "max": 982736, "sum": 982736.0, "min": 982736}, "Max Records Seen Between Resets": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Reset Count": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1537270277.878493, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 13}, "StartTime": 1537270277.327868}
#
# [09/18/2018 11:31:17 INFO 139994573981504] #throughput_metric: host=algo-1, train throughput=127329.624561 records/second
# [09/18/2018 11:31:17 INFO 139994573981504] #quality_metric: host=algo-1, epoch=14, batch=0 train binary_classification_accuracy <score>=0.653
# [09/18/2018 11:31:17 INFO 139994573981504] #quality_metric: host=algo-1, epoch=14, batch=0 train binary_classification_cross_entropy <loss>=0.583354248047
# [09/18/2018 11:31:17 INFO 139994573981504] #quality_metric: host=algo-1, epoch=14, batch=0 train binary_f_1.000 <score>=0.0280112044818
# [09/18/2018 11:31:18 INFO 139994573981504] #quality_metric: host=algo-1, epoch=14, train binary_classification_accuracy <score>=0.713478873239
# [09/18/2018 11:31:18 INFO 139994573981504] #quality_metric: host=algo-1, epoch=14, train binary_classification_cross_entropy <loss>=0.556968818342
# [09/18/2018 11:31:18 INFO 139994573981504] #quality_metric: host=algo-1, epoch=14, train binary_f_1.000 <score>=0.155436542533
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 619.3711757659912, "sum": 619.3711757659912, "min": 619.3711757659912}}, "EndTime": 1537270278.498171, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1537270277.878351}
#
# [09/18/2018 11:31:18 INFO 139994573981504] #progress_metric: host=algo-1, completed 15 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Total Batches Seen": {"count": 1, "max": 1066, "sum": 1066.0, "min": 1066}, "Total Records Seen": {"count": 1, "max": 1052860, "sum": 1052860.0, "min": 1052860}, "Max Records Seen Between Resets": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Reset Count": {"count": 1, "max": 16, "sum": 16.0, "min": 16}}, "EndTime": 1537270278.498374, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 14}, "StartTime": 1537270277.878773}
#
# [09/18/2018 11:31:18 INFO 139994573981504] #throughput_metric: host=algo-1, train throughput=113157.073648 records/second
# [09/18/2018 11:31:18 INFO 139994573981504] #quality_metric: host=algo-1, epoch=15, batch=0 train binary_classification_accuracy <score>=0.663
# [09/18/2018 11:31:18 INFO 139994573981504] #quality_metric: host=algo-1, epoch=15, batch=0 train binary_classification_cross_entropy <loss>=0.578631408691
# [09/18/2018 11:31:18 INFO 139994573981504] #quality_metric: host=algo-1, epoch=15, batch=0 train binary_f_1.000 <score>=0.0817438692098
# [09/18/2018 11:31:19 INFO 139994573981504] #quality_metric: host=algo-1, epoch=15, train binary_classification_accuracy <score>=0.720549295775
# [09/18/2018 11:31:19 INFO 139994573981504] #quality_metric: host=algo-1, epoch=15, train binary_classification_cross_entropy <loss>=0.552634160431
# [09/18/2018 11:31:19 INFO 139994573981504] #quality_metric: host=algo-1, epoch=15, train binary_f_1.000 <score>=0.195319787484
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 603.5430431365967, "sum": 603.5430431365967, "min": 603.5430431365967}}, "EndTime": 1537270279.102209, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1537270278.498235}
#
# [09/18/2018 11:31:19 INFO 139994573981504] #progress_metric: host=algo-1, completed 16 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Total Batches Seen": {"count": 1, "max": 1137, "sum": 1137.0, "min": 1137}, "Total Records Seen": {"count": 1, "max": 1122984, "sum": 1122984.0, "min": 1122984}, "Max Records Seen Between Resets": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1537270279.102412, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 15}, "StartTime": 1537270278.498638}
#
# [09/18/2018 11:31:19 INFO 139994573981504] #throughput_metric: host=algo-1, train throughput=116120.496639 records/second
# [09/18/2018 11:31:19 INFO 139994573981504] #quality_metric: host=algo-1, epoch=16, batch=0 train binary_classification_accuracy <score>=0.678
# [09/18/2018 11:31:19 INFO 139994573981504] #quality_metric: host=algo-1, epoch=16, batch=0 train binary_classification_cross_entropy <loss>=0.573879760742
# [09/18/2018 11:31:19 INFO 139994573981504] #quality_metric: host=algo-1, epoch=16, batch=0 train binary_f_1.000 <score>=0.157068062827
# [09/18/2018 11:31:19 INFO 139994573981504] #quality_metric: host=algo-1, epoch=16, train binary_classification_accuracy <score>=0.726225352113
# [09/18/2018 11:31:19 INFO 139994573981504] #quality_metric: host=algo-1, epoch=16, train binary_classification_cross_entropy <loss>=0.548266945852
# [09/18/2018 11:31:19 INFO 139994573981504] #quality_metric: host=algo-1, epoch=16, train binary_f_1.000 <score>=0.22637904959
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 573.889970779419, "sum": 573.889970779419, "min": 573.889970779419}}, "EndTime": 1537270279.676605, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1537270279.102279}
#
# [09/18/2018 11:31:19 INFO 139994573981504] #progress_metric: host=algo-1, completed 17 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Total Batches Seen": {"count": 1, "max": 1208, "sum": 1208.0, "min": 1208}, "Total Records Seen": {"count": 1, "max": 1193108, "sum": 1193108.0, "min": 1193108}, "Max Records Seen Between Resets": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Reset Count": {"count": 1, "max": 18, "sum": 18.0, "min": 18}}, "EndTime": 1537270279.676799, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 16}, "StartTime": 1537270279.102687}
#
# [09/18/2018 11:31:19 INFO 139994573981504] #throughput_metric: host=algo-1, train throughput=122118.730014 records/second
# [09/18/2018 11:31:19 INFO 139994573981504] #quality_metric: host=algo-1, epoch=17, batch=0 train binary_classification_accuracy <score>=0.684
# [09/18/2018 11:31:19 INFO 139994573981504] #quality_metric: host=algo-1, epoch=17, batch=0 train binary_classification_cross_entropy <loss>=0.569097290039
# [09/18/2018 11:31:19 INFO 139994573981504] #quality_metric: host=algo-1, epoch=17, batch=0 train binary_f_1.000 <score>=0.185567010309
# [09/18/2018 11:31:20 INFO 139994573981504] #quality_metric: host=algo-1, epoch=17, train binary_classification_accuracy <score>=0.731309859155
# [09/18/2018 11:31:20 INFO 139994573981504] #quality_metric: host=algo-1, epoch=17, train binary_classification_cross_entropy <loss>=0.543866638613
# [09/18/2018 11:31:20 INFO 139994573981504] #quality_metric: host=algo-1, epoch=17, train binary_f_1.000 <score>=0.253258699652
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 532.4900150299072, "sum": 532.4900150299072, "min": 532.4900150299072}}, "EndTime": 1537270280.209815, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1537270279.676667}
#
# [09/18/2018 11:31:20 INFO 139994573981504] #progress_metric: host=algo-1, completed 18 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Total Batches Seen": {"count": 1, "max": 1279, "sum": 1279.0, "min": 1279}, "Total Records Seen": {"count": 1, "max": 1263232, "sum": 1263232.0, "min": 1263232}, "Max Records Seen Between Resets": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Reset Count": {"count": 1, "max": 19, "sum": 19.0, "min": 19}}, "EndTime": 1537270280.210042, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 17}, "StartTime": 1537270279.677296}
#
# [09/18/2018 11:31:20 INFO 139994573981504] #throughput_metric: host=algo-1, train throughput=131602.758444 records/second
# [09/18/2018 11:31:20 INFO 139994573981504] #quality_metric: host=algo-1, epoch=18, batch=0 train binary_classification_accuracy <score>=0.691
# [09/18/2018 11:31:20 INFO 139994573981504] #quality_metric: host=algo-1, epoch=18, batch=0 train binary_classification_cross_entropy <loss>=0.564283691406
# [09/18/2018 11:31:20 INFO 139994573981504] #quality_metric: host=algo-1, epoch=18, batch=0 train binary_f_1.000 <score>=0.221662468514
# [09/18/2018 11:31:20 INFO 139994573981504] #quality_metric: host=algo-1, epoch=18, train binary_classification_accuracy <score>=0.736042253521
# [09/18/2018 11:31:20 INFO 139994573981504] #quality_metric: host=algo-1, epoch=18, train binary_classification_cross_entropy <loss>=0.539433775136
# [09/18/2018 11:31:20 INFO 139994573981504] #quality_metric: host=algo-1, epoch=18, train binary_f_1.000 <score>=0.277608603477
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 587.6109600067139, "sum": 587.6109600067139, "min": 587.6109600067139}}, "EndTime": 1537270280.797964, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1537270280.209886}
#
# [09/18/2018 11:31:20 INFO 139994573981504] #progress_metric: host=algo-1, completed 19 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Total Batches Seen": {"count": 1, "max": 1350, "sum": 1350.0, "min": 1350}, "Total Records Seen": {"count": 1, "max": 1333356, "sum": 1333356.0, "min": 1333356}, "Max Records Seen Between Resets": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Reset Count": {"count": 1, "max": 20, "sum": 20.0, "min": 20}}, "EndTime": 1537270280.79819, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 18}, "StartTime": 1537270280.210321}
#
# [09/18/2018 11:31:20 INFO 139994573981504] #throughput_metric: host=algo-1, train throughput=119260.957625 records/second
# [09/18/2018 11:31:20 INFO 139994573981504] #quality_metric: host=algo-1, epoch=19, batch=0 train binary_classification_accuracy <score>=0.694
# [09/18/2018 11:31:20 INFO 139994573981504] #quality_metric: host=algo-1, epoch=19, batch=0 train binary_classification_cross_entropy <loss>=0.55943939209
# [09/18/2018 11:31:20 INFO 139994573981504] #quality_metric: host=algo-1, epoch=19, batch=0 train binary_f_1.000 <score>=0.235
# [09/18/2018 11:31:21 INFO 139994573981504] #quality_metric: host=algo-1, epoch=19, train binary_classification_accuracy <score>=0.740169014085
# [09/18/2018 11:31:21 INFO 139994573981504] #quality_metric: host=algo-1, epoch=19, train binary_classification_cross_entropy <loss>=0.534969714957
# [09/18/2018 11:31:21 INFO 139994573981504] #quality_metric: host=algo-1, epoch=19, train binary_f_1.000 <score>=0.298181541505
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 599.236011505127, "sum": 599.236011505127, "min": 599.236011505127}}, "EndTime": 1537270281.397737, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1537270280.798029}
#
# [09/18/2018 11:31:21 INFO 139994573981504] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Total Batches Seen": {"count": 1, "max": 1421, "sum": 1421.0, "min": 1421}, "Total Records Seen": {"count": 1, "max": 1403480, "sum": 1403480.0, "min": 1403480}, "Max Records Seen Between Resets": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Reset Count": {"count": 1, "max": 21, "sum": 21.0, "min": 21}}, "EndTime": 1537270281.397918, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 19}, "StartTime": 1537270280.798463}
#
# [09/18/2018 11:31:21 INFO 139994573981504] #throughput_metric: host=algo-1, train throughput=116957.936256 records/second
# [09/18/2018 11:31:21 INFO 139994573981504] #quality_metric: host=algo-1, epoch=20, batch=0 train binary_classification_accuracy <score>=0.699
# [09/18/2018 11:31:21 INFO 139994573981504] #quality_metric: host=algo-1, epoch=20, batch=0 train binary_classification_cross_entropy <loss>=0.554565795898
# [09/18/2018 11:31:21 INFO 139994573981504] #quality_metric: host=algo-1, epoch=20, batch=0 train binary_f_1.000 <score>=0.256790123457
# ...
# [09/18/2018 11:32:04 INFO 139994573981504] #quality_metric: host=algo-1, epoch=94, batch=0 train binary_classification_cross_entropy <loss>=0.251598999023
# [09/18/2018 11:32:04 INFO 139994573981504] #quality_metric: host=algo-1, epoch=94, batch=0 train binary_f_1.000 <score>=0.927272727273
# [09/18/2018 11:32:05 INFO 139994573981504] #quality_metric: host=algo-1, epoch=94, train binary_classification_accuracy <score>=0.954211267606
# [09/18/2018 11:32:05 INFO 139994573981504] #quality_metric: host=algo-1, epoch=94, train binary_classification_cross_entropy <loss>=0.250812513539
# [09/18/2018 11:32:05 INFO 139994573981504] #quality_metric: host=algo-1, epoch=94, train binary_f_1.000 <score>=0.92170227114
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 564.0709400177002, "sum": 564.0709400177002, "min": 564.0709400177002}}, "EndTime": 1537270325.02603, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1537270324.461501}
#
# [09/18/2018 11:32:05 INFO 139994573981504] #progress_metric: host=algo-1, completed 95 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Total Batches Seen": {"count": 1, "max": 6746, "sum": 6746.0, "min": 6746}, "Total Records Seen": {"count": 1, "max": 6662780, "sum": 6662780.0, "min": 6662780}, "Max Records Seen Between Resets": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Reset Count": {"count": 1, "max": 96, "sum": 96.0, "min": 96}}, "EndTime": 1537270325.026239, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 94}, "StartTime": 1537270324.461929}
#
# [09/18/2018 11:32:05 INFO 139994573981504] #throughput_metric: host=algo-1, train throughput=124240.344593 records/second
# [09/18/2018 11:32:05 INFO 139994573981504] #quality_metric: host=algo-1, epoch=95, batch=0 train binary_classification_accuracy <score>=0.954
# [09/18/2018 11:32:05 INFO 139994573981504] #quality_metric: host=algo-1, epoch=95, batch=0 train binary_classification_cross_entropy <loss>=0.248872177124
# [09/18/2018 11:32:05 INFO 139994573981504] #quality_metric: host=algo-1, epoch=95, batch=0 train binary_f_1.000 <score>=0.930513595166
# [09/18/2018 11:32:05 INFO 139994573981504] #quality_metric: host=algo-1, epoch=95, train binary_classification_accuracy <score>=0.955309859155
# [09/18/2018 11:32:05 INFO 139994573981504] #quality_metric: host=algo-1, epoch=95, train binary_classification_cross_entropy <loss>=0.248279748621
# [09/18/2018 11:32:05 INFO 139994573981504] #quality_metric: host=algo-1, epoch=95, train binary_f_1.000 <score>=0.923709456373
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 575.2098560333252, "sum": 575.2098560333252, "min": 575.2098560333252}}, "EndTime": 1537270325.601792, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1537270325.026097}
#
# [09/18/2018 11:32:05 INFO 139994573981504] #progress_metric: host=algo-1, completed 96 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Total Batches Seen": {"count": 1, "max": 6817, "sum": 6817.0, "min": 6817}, "Total Records Seen": {"count": 1, "max": 6732904, "sum": 6732904.0, "min": 6732904}, "Max Records Seen Between Resets": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Reset Count": {"count": 1, "max": 97, "sum": 97.0, "min": 97}}, "EndTime": 1537270325.601995, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 95}, "StartTime": 1537270325.026551}
#
# [09/18/2018 11:32:05 INFO 139994573981504] #throughput_metric: host=algo-1, train throughput=121839.082896 records/second
# [09/18/2018 11:32:05 INFO 139994573981504] #quality_metric: host=algo-1, epoch=96, batch=0 train binary_classification_accuracy <score>=0.955
# [09/18/2018 11:32:05 INFO 139994573981504] #quality_metric: host=algo-1, epoch=96, batch=0 train binary_classification_cross_entropy <loss>=0.246177841187
# [09/18/2018 11:32:05 INFO 139994573981504] #quality_metric: host=algo-1, epoch=96, batch=0 train binary_f_1.000 <score>=0.932126696833
# [09/18/2018 11:32:06 INFO 139994573981504] #quality_metric: host=algo-1, epoch=96, train binary_classification_accuracy <score>=0.956535211268
# [09/18/2018 11:32:06 INFO 139994573981504] #quality_metric: host=algo-1, epoch=96, train binary_classification_cross_entropy <loss>=0.245776602947
# [09/18/2018 11:32:06 INFO 139994573981504] #quality_metric: host=algo-1, epoch=96, train binary_f_1.000 <score>=0.92594903297
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 590.6150341033936, "sum": 590.6150341033936, "min": 590.6150341033936}}, "EndTime": 1537270326.192916, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1537270325.601849}
#
# [09/18/2018 11:32:06 INFO 139994573981504] #progress_metric: host=algo-1, completed 97 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Total Batches Seen": {"count": 1, "max": 6888, "sum": 6888.0, "min": 6888}, "Total Records Seen": {"count": 1, "max": 6803028, "sum": 6803028.0, "min": 6803028}, "Max Records Seen Between Resets": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Reset Count": {"count": 1, "max": 98, "sum": 98.0, "min": 98}}, "EndTime": 1537270326.193154, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 96}, "StartTime": 1537270325.602268}
#
# [09/18/2018 11:32:06 INFO 139994573981504] #throughput_metric: host=algo-1, train throughput=118649.524325 records/second
# [09/18/2018 11:32:06 INFO 139994573981504] #quality_metric: host=algo-1, epoch=97, batch=0 train binary_classification_accuracy <score>=0.955
# [09/18/2018 11:32:06 INFO 139994573981504] #quality_metric: host=algo-1, epoch=97, batch=0 train binary_classification_cross_entropy <loss>=0.243515579224
# [09/18/2018 11:32:06 INFO 139994573981504] #quality_metric: host=algo-1, epoch=97, batch=0 train binary_f_1.000 <score>=0.932126696833
# [09/18/2018 11:32:06 INFO 139994573981504] #quality_metric: host=algo-1, epoch=97, train binary_classification_accuracy <score>=0.957535211268
# [09/18/2018 11:32:06 INFO 139994573981504] #quality_metric: host=algo-1, epoch=97, train binary_classification_cross_entropy <loss>=0.243302737169
# [09/18/2018 11:32:06 INFO 139994573981504] #quality_metric: host=algo-1, epoch=97, train binary_f_1.000 <score>=0.927768860353
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 551.2690544128418, "sum": 551.2690544128418, "min": 551.2690544128418}}, "EndTime": 1537270326.744739, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1537270326.192998}
#
# [09/18/2018 11:32:06 INFO 139994573981504] #progress_metric: host=algo-1, completed 98 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Total Batches Seen": {"count": 1, "max": 6959, "sum": 6959.0, "min": 6959}, "Total Records Seen": {"count": 1, "max": 6873152, "sum": 6873152.0, "min": 6873152}, "Max Records Seen Between Resets": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Reset Count": {"count": 1, "max": 99, "sum": 99.0, "min": 99}}, "EndTime": 1537270326.744971, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 97}, "StartTime": 1537270326.193441}
#
# [09/18/2018 11:32:06 INFO 139994573981504] #throughput_metric: host=algo-1, train throughput=127118.688372 records/second
# [09/18/2018 11:32:06 INFO 139994573981504] #quality_metric: host=algo-1, epoch=98, batch=0 train binary_classification_accuracy <score>=0.956
# [09/18/2018 11:32:06 INFO 139994573981504] #quality_metric: host=algo-1, epoch=98, batch=0 train binary_classification_cross_entropy <loss>=0.24088508606
# [09/18/2018 11:32:06 INFO 139994573981504] #quality_metric: host=algo-1, epoch=98, batch=0 train binary_f_1.000 <score>=0.933734939759
# [09/18/2018 11:32:07 INFO 139994573981504] #quality_metric: host=algo-1, epoch=98, train binary_classification_accuracy <score>=0.958436619718
# [09/18/2018 11:32:07 INFO 139994573981504] #quality_metric: host=algo-1, epoch=98, train binary_classification_cross_entropy <loss>=0.240857822472
# [09/18/2018 11:32:07 INFO 139994573981504] #quality_metric: host=algo-1, epoch=98, train binary_f_1.000 <score>=0.929400224886
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 572.2510814666748, "sum": 572.2510814666748, "min": 572.2510814666748}}, "EndTime": 1537270327.317532, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1537270326.744801}
#
# [09/18/2018 11:32:07 INFO 139994573981504] #progress_metric: host=algo-1, completed 99 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Total Batches Seen": {"count": 1, "max": 7030, "sum": 7030.0, "min": 7030}, "Total Records Seen": {"count": 1, "max": 6943276, "sum": 6943276.0, "min": 6943276}, "Max Records Seen Between Resets": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Reset Count": {"count": 1, "max": 100, "sum": 100.0, "min": 100}}, "EndTime": 1537270327.317738, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 98}, "StartTime": 1537270326.745243}
#
# [09/18/2018 11:32:07 INFO 139994573981504] #throughput_metric: host=algo-1, train throughput=122464.235088 records/second
# [09/18/2018 11:32:07 INFO 139994573981504] #quality_metric: host=algo-1, epoch=99, batch=0 train binary_classification_accuracy <score>=0.958
# [09/18/2018 11:32:07 INFO 139994573981504] #quality_metric: host=algo-1, epoch=99, batch=0 train binary_classification_cross_entropy <loss>=0.238285964966
# [09/18/2018 11:32:07 INFO 139994573981504] #quality_metric: host=algo-1, epoch=99, batch=0 train binary_f_1.000 <score>=0.936936936937
# [09/18/2018 11:32:07 INFO 139994573981504] #quality_metric: host=algo-1, epoch=99, train binary_classification_accuracy <score>=0.959169014085
# [09/18/2018 11:32:07 INFO 139994573981504] #quality_metric: host=algo-1, epoch=99, train binary_classification_cross_entropy <loss>=0.238441539926
# [09/18/2018 11:32:07 INFO 139994573981504] #quality_metric: host=algo-1, epoch=99, train binary_f_1.000 <score>=0.930733758631
# [09/18/2018 11:32:07 INFO 139994573981504] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.959169014085
# [09/18/2018 11:32:07 INFO 139994573981504] #quality_metric: host=algo-1, train binary_classification_cross_entropy <loss>=0.238441539926
# [09/18/2018 11:32:07 INFO 139994573981504] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.930733758631
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 599.0359783172607, "sum": 599.0359783172607, "min": 599.0359783172607}}, "EndTime": 1537270327.917145, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1537270327.317586}
#
# [09/18/2018 11:32:07 INFO 139994573981504] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Batches Since Last Reset": {"count": 1, "max": 71, "sum": 71.0, "min": 71}, "Number of Records Since Last Reset": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Total Batches Seen": {"count": 1, "max": 7101, "sum": 7101.0, "min": 7101}, "Total Records Seen": {"count": 1, "max": 7013400, "sum": 7013400.0, "min": 7013400}, "Max Records Seen Between Resets": {"count": 1, "max": 70124, "sum": 70124.0, "min": 70124}, "Reset Count": {"count": 1, "max": 101, "sum": 101.0, "min": 101}}, "EndTime": 1537270327.917342, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 99}, "StartTime": 1537270327.318078}
#
# [09/18/2018 11:32:07 INFO 139994573981504] #throughput_metric: host=algo-1, train throughput=116993.851883 records/second
# [09/18/2018 11:32:07 WARNING 139994573981504] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [09/18/2018 11:32:07 INFO 139994573981504] Pulling entire model from kvstore to finalize
# #metrics {"Metrics": {"finalize.time": {"count": 1, "max": 3.3740997314453125, "sum": 3.3740997314453125, "min": 3.3740997314453125}}, "EndTime": 1537270327.920982, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1537270327.917201}
#
# [09/18/2018 11:32:07 INFO 139994573981504] Saved checkpoint to "/tmp/tmpbyCSSb/state-0001.params"
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 18, "sum": 18.0, "min": 18}, "Number of Batches Since Last Reset": {"count": 1, "max": 18, "sum": 18.0, "min": 18}, "Number of Records Since Last Reset": {"count": 1, "max": 17531, "sum": 17531.0, "min": 17531}, "Total Batches Seen": {"count": 1, "max": 18, "sum": 18.0, "min": 18}, "Total Records Seen": {"count": 1, "max": 17531, "sum": 17531.0, "min": 17531}, "Max Records Seen Between Resets": {"count": 1, "max": 17531, "sum": 17531.0, "min": 17531}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1537270328.066223, "Dimensions": {"Host": "algo-1", "Meta": "test_data_iter", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1537270327.940633}
#
# [09/18/2018 11:32:08 INFO 139994573981504] #test_score (algo-1) : ('binary_classification_accuracy', 0.72386058981233248)
# [09/18/2018 11:32:08 INFO 139994573981504] #test_score (algo-1) : ('binary_classification_cross_entropy', 0.55949882571297804)
# [09/18/2018 11:32:08 INFO 139994573981504] #test_score (algo-1) : ('binary_f_1.000', 0.3649481831300013)
# [09/18/2018 11:32:08 INFO 139994573981504] #quality_metric: host=algo-1, test binary_classification_accuracy <score>=0.723860589812
# [09/18/2018 11:32:08 INFO 139994573981504] #quality_metric: host=algo-1, test binary_classification_cross_entropy <loss>=0.559498825713
# [09/18/2018 11:32:08 INFO 139994573981504] #quality_metric: host=algo-1, test binary_f_1.000 <score>=0.36494818313
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 58386.204957962036, "sum": 58386.204957962036, "min": 58386.204957962036}, "setuptime": {"count": 1, "max": 37.390947341918945, "sum": 37.390947341918945, "min": 37.390947341918945}}, "EndTime": 1537270328.068326, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1537270327.921026}
#
# ===== Job Complete =====
# Billable seconds: 156

# %% [markdown]
# ### Deploy model

# %%
fm_predictor = fm.deploy(instance_type='ml.c4.xlarge', initial_instance_count=1)
# Out:
# INFO:sagemaker:Creating model with name: factorization-machines-2018-09-18-11-36-03-018
# INFO:sagemaker:Creating endpoint with name factorization-machines-2018-09-18-11-27-58-824
# --------------------------------------------------------------!

# %% [markdown]
# ### Run predictions

# %%
def fm_serializer(data):
    js = {'instances': []}
    for row in data:
        js['instances'].append({'features': row.tolist()})
    #print js
    return json.dumps(js)

fm_predictor.content_type = 'application/json'
fm_predictor.serializer = fm_serializer
fm_predictor.deserializer = json_deserializer

# %%
predictions = []
for array in np.array_split(X_test.toarray(), 550):
    result = fm_predictor.predict(array)
    predictions += [r['predicted_label'] for r in result['predictions']]

predictions = np.array(predictions)

# %% [markdown]
# Three experiments were run
# 1. One, with all data and considering if a cust bought an item more than thrice in an year then that's a positive feedback on that item. Results was highly biased towards outcome of 0 since the data is heavily scewed towards 0.
# 2. Second, with all data and considering if a cust bought an item twice or more in an year then that's a positive feedback on that item. Lowering the threshold in the data, increased the percentage of positive labels a bit the result improved a bit but still highly biased
# 3. The final experiment was by under-sampling the data (remmoving random 50% of the 0 labeled records) This gave even better results.

# %% [markdown]
# Result of Experiement number 3

# %%
pd.crosstab(Y_test, predictions, rownames=['actuals'], colnames=['predictions'])
# Out:
# predictions    0.0   1.0
# actuals
# 0.0          11299   756
# 1.0           4085  1391

# %% [markdown]
# Result of experiment number 2

# %%
pd.crosstab(Y_test, predictions, rownames=['actuals'], colnames=['predictions'])
# Out:
# predictions  0.000  1.000
# actuals
# 0.000        23264    702
# 1.000         4594    974

# %% [markdown]
# Result of experiment number 1

# %%
pd.crosstab(Y_test, predictions, rownames=['actuals'], colnames=['predictions'])
# Out:
# predictions  0.000  1.000
# actuals
# 0.000        28579     98
# 1.000          799     58

# %% [markdown]
# ## Analysis
# 1. Transaction data is highly skewed against repeat sale. So making the model learn positive results will involve a lot of negative sampling.
# 2. We should have better way of gathering implicit metric for dislikes. One way is from click stream, if we capture that these the 5 pizzas shown to the user and this is the one she chose.
# 3. We should also do a content-based analysis if we capture the metadata  for different menu like bread_type,toppings, duration in oven etc. Then we can create similarity of ingredients and do a content-based recommendation
# 4. We are also doing Market Basket Analysis, to see whether there is any affinity of two types of Menu occuring together. So that if one is bought we can recommend the other. But the data doesn't show any such trend.
